# %% [markdown]
# Student name: **Siddharth Prince**
# Student ID: **23052058**

# %% [markdown]
# # GP Multiple runs on an arbitrary Symbolic Regression Problem.

# %% [markdown]
# Now we add elitism to our system. Note that this is packaged up as an other algorithm, so it will work with virtually any other notebook we've looked at.
#
# The key thing to note is how we include that functionality, as it is **not** a standard algorithm in DEAP.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_57128/3391910190.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Install DEAP.

# %%
# !pip install deap

# %% [markdown]
# Python will import from files in the working directory, so we change to the one we need.

# %% [markdown]
# Import our tools.

# %%
import operator
import math
import random

import numpy

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp

import csv



import matplotlib.pyplot as plt

import itertools
import networkx as nx

# %% [markdown]
# Set our Genetic Programming parameters, one of which is now the number of runs.

# %%
# Genetic Programming constants:
POPULATION_SIZE = 300
P_CROSSOVER = 0.9
P_MUTATION = 0.01
MAX_GENERATIONS = 50
HALL_OF_FAME_SIZE = 10

N_RUNS = 30

# %% [markdown]
# Set the random seed.

# %%
RANDOM_SEED = 412
random.seed(RANDOM_SEED)

# %% [markdown]
# GP-Specific constants.

# %%
MIN_TREE_HEIGHT = 3
MAX_TREE_HEIGHT = 5
LIMIT_TREE_HEIGHT = 17
MUT_MIN_TREE_HEIGHT = 0
MUT_MAX_TREE_HEIGHT = 2

# %% [markdown]
# Read in the data. Notice that this time we can use the path, so there's no need to change to that folder.

# %%
with open("./input.csv") as inputData:
    n_rows = sum(1 for line in inputData)
with open("./input.csv") as inputData:
    reader = csv.reader(inputData)
    data = list(list(float(elem) for elem in row) for row in reader)
    dataSorted = sorted(data, key = lambda x: x[0])
print(dataSorted)
# Out:
# [[0.05, -5.920472905375246e-06], [0.15, -0.0004197490074396078], [0.25, -0.002744011962215962], [0.35, -0.008657128698830847], [0.45, -0.01888024838080345], [0.55, -0.03281107258572483], [0.65, -0.04893233110534319], [0.75, -0.06560096236716338], [0.85, -0.08166740530354051], [0.95, -0.09650694284366339], [1.05, -0.109383732295163], [1.15, -0.1184462034256205], [1.25, -0.1198965923123214], [1.35, -0.1078791480794438], [1.45, -0.07538681808122603], [1.55, -0.01609080392499869], [1.65, 0.07339461083608066], [1.75, 0.1915363368441183], [1.85, 0.3309083626081094], [1.95, 0.4786681161315149], [2.05, 0.6185024362862599], [2.15, 0.733608667330639], [2.25, 0.809947806298645], [2.35, 0.8389089510601118], [2.45, 0.8186871380016217], [2.55, 0.7540465107814242], [2.65, 0.6546009929076181], [2.75, 0.5321544028706404], [2.85, 0.3978806420930439], [2.95, 0.2601276974469659], [3.05, 0.1234051649414878], [3.15, -0.01126090293203677], [3.25, -0.1448333887352612], [3.35, -0.278182980554089], [3.45, -0.4101234722641215], [3.55, -0.5362052262266439], [3.649999999999999, -0.6486636751053088], [3.75, -0.7375694202701226], [3.85, -0.7928746150065994], [3.95, -0.8067957595201792], [4.05, -0.775882243022089], [4.15, -0.7022105431691226], [4.25, -0.5933828647782589], [4.35, -0.4613247003684112], [4.45, -0.3201803624891209], [4.55, -0.1838193240995138], [4.65, -0.06353862043288007], [4.75, 0.03353251584373382], [4.85, 0.1050201247164789], [4.95, 0.1528419944793204], [5.05, 0.1819037178326882], [5.150000000000001, 0.1983465163192565], [5.25, 0.207808845646738], [5.35, 0.21411380276363], [5.450000000000001, 0.2186475486424381], [5.55, 0.220495761638348], [5.65, 0.2172098057887873], [5.750000000000001, 0.2059303444221521], [5.85, 0.1845345578223014], [5.95, 0.1525012685657079], [6.050000000000001, 0.1112902435947829], [6.15, 0.06417488813893034], [6.25, 0.01561163500816949], [6.350000000000001, -0.02966156204610288], [6.45, -0.06755482772181315], [6.55, -0.09535622462919775], [6.650000000000001, -0.1121040527995223], [6.75, -0.1185458646762452], [6.85, -0.1167340980679437], [6.950000000000001, -0.1093909383615195], [7.05, -0.09921681054057341], [7.15, -0.08831177985834694], [7.250000000000002, -0.0778333184274862], [7.35, -0.0679429329999461], [7.45, -0.05801810054578526], [7.550000000000001, -0.04704394290562166], [7.65, -0.03406468214166072], [7.75, -0.01857349990905337], [7.850000000000001, -0.0007476897199050684], [7.95, 0.01851620555565741], [8.05, 0.03775899036260407], [8.150000000000002, 0.05525309487567331], [8.25, 0.06935268923669112], [8.35, 0.07881262857403715], [8.450000000000001, 0.08300536348115052], [8.55, 0.08199608838545486], [8.65, 0.07647337762906103], [8.750000000000002, 0.06756590687044263], [8.85, 0.05659811005778664], [8.95, 0.04484486737005573], [9.05, 0.03333770111075977], [9.15, 0.02275613893719095], [9.25, 0.01341375547071004], [9.350000000000001, 0.005325315277578894], [9.45, -0.001675269226643721], [9.55, -0.007803671898095639], [9.65, -0.01321537564831456], [9.75, -0.01794152679802587], [9.85, -0.02187959202330041], [9.950000000000001, -0.02483287990250848]]

# %%
dataNumpy = numpy.array(dataSorted)
plt.plot(dataNumpy[:,0], dataNumpy[:,1])

# %% [markdown]
# Define our fitness function.

# %%
def evalSymbReg(individual):
    # Transform the tree expression in a callable function
    func = toolbox.compile(expr=individual)
    # Evaluate the sum of squared difference between the expression and the target values
    # [print(row[-1]) for row in data]
    diff = sum((func(*row[:-1]) - row[-1])**2 for row in data)
    error = diff/n_rows
    if (error>10):
        error=10
    #return error, individual.height
    nodes, edges, labels = gp.graph(individual)
    return error, len(nodes)

# %% [markdown]
# Define a protected division function.

# %%
# Protected functions
def protectedDiv(left, right):
    try:
        return left / right
    except ZeroDivisionError:
        return 1


def psin(n):
    try:
        return numpy.sin(n)
    except Exception:
        return numpy.nan

def pcos(n):
    try:
        return numpy.cos(n)
    except Exception:
        return numpy.nan

def pow2(n):
    return operator.pow(n, 2)

# %% [markdown]
# Add our functions and terminals.

# %%
pset = gp.PrimitiveSet("MAIN", 1) # number of inputs!!!
pset.addPrimitive(operator.add, 2)
pset.addPrimitive(operator.sub, 2)
pset.addPrimitive(operator.mul, 2)
pset.addPrimitive(protectedDiv, 2)
pset.addPrimitive(operator.neg, 1)
pset.addPrimitive(math.cos, 1)
pset.addPrimitive(math.sin, 1)
pset.addEphemeralConstant("rand101", lambda: random.random())
# Out:
# /home/sprince0031/.local/lib/python3.10/site-packages/deap/gp.py:254: RuntimeWarning: Ephemeral rand101 function cannot be pickled because its generating function is a lambda function. Use functools.partial instead.
#   warnings.warn("Ephemeral {name} function cannot be "

# %% [markdown]
# Create our toolbox. This is very similar to the Symbolic Regression notebook except we are using the parameters declared up above.

# %%
toolbox = base.Toolbox()

creator.create("FitnessMin", base.Fitness, weights=(-1.0,-1.0))
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)

toolbox.register("expr", gp.genHalfAndHalf, pset=pset, min_=1, max_=2)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.expr)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("compile", gp.compile, pset=pset)

toolbox.register("evaluate", evalSymbReg)
#toolbox.register("select", tools.selNSGA2)
toolbox.register("select", tools.selTournament, tournsize=5)

toolbox.register("mate", gp.cxOnePoint)
toolbox.register("expr_mut", gp.genFull, min_=0, max_=5)
toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr_mut, pset=pset)

toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))
toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=17))

# %% [markdown]
# Create our statistics. These are a bit more complex than the GA ones because we want to keep track of fitness and size for all runs.

# %%
maxListFitness = []
avgListFitness = []
minListFitness = []
stdListFitness = []

maxListSize = []
avgListSize = []
minListSize = []
stdListSize = []

bestIndividualsForNRuns = []

# %% [markdown]
# Now the magic happens and we run **N_RUNS** times. Always start with a small number of runs and generations to make sure that everything is working properly before you commit to a larger number. That way, if something goes horribly wrong, Python won't replicate it 30 times before giving you back control!

# %%
for r in range(0, N_RUNS):
    population = toolbox.population(n=POPULATION_SIZE)
    # define the hall-of-fame object:
    hof = tools.HallOfFame(HALL_OF_FAME_SIZE)   


    # Create our statistics
    stats_fit = tools.Statistics(lambda ind: ind.fitness.values)
    stats_size = tools.Statistics(len)
    mstats = tools.MultiStatistics(fitness=stats_fit, size=stats_size)
    mstats.register("avg", numpy.mean)
    mstats.register("std", numpy.std)
    mstats.register("min", numpy.min)
    mstats.register("max", numpy.max)
    
    
    # Which run are we on?
    print("\n\nCurrently on run", r, "of",N_RUNS)
    
    
    # It's usually a good idea to turn off verbose when conducting multiple runs
    population, logbook = algorithms.eaSimple(population,
                                                  toolbox,
                                                  cxpb=P_CROSSOVER,
                                                  mutpb=P_MUTATION,
                                                  ngen=MAX_GENERATIONS,
                                                  stats=mstats,
                                                  halloffame=hof,
                                                  verbose=False)
    
    #maxFitnessValues, meanFitnessValues = logbook.chapters['fitness'].select("min", "avg")
    meanFitnessValues, stdFitnessValues, minFitnessValues, maxFitnessValues  = logbook.chapters['fitness'].select("avg", "std", "min", "max")
    meanSizeValues, stdSizeValues, minSizeValues, maxSizeValues  = logbook.chapters['size'].select("avg", "std", "min", "max")


    # Save statistics for this run:
    avgListFitness.append(meanFitnessValues)
    stdListFitness.append(stdFitnessValues)
    minListFitness.append(minFitnessValues)
    maxListFitness.append(maxFitnessValues)
    
    avgListSize.append(meanSizeValues)
    stdListSize.append(stdSizeValues)
    minListSize.append(minSizeValues)
    maxListSize.append(maxSizeValues)

    # print info for best solution found:
    best = hof.items[0]
    print("-- Best Individual = ", best)
    print("-- length={}, height={}".format(len(best), best.height))
    print("-- Best Fitness = ", best.fitness.values[0])

    bestInd = toolbox.compile(expr=best)
    bestIndData = [bestInd(row[0]) for row in dataSorted]
    bestIndividualsForNRuns.append((bestIndData, best.fitness.values[0]))
# Out:
# Currently on run 0 of 30
# -- Best Individual =  mul(0.6127054166079398, sin(sub(sub(ARG0, sin(sub(ARG0, sub(ARG0, sin(sin(sub(ARG0, sin(sin(ARG0))))))))), sin(sub(ARG0, sub(sin(sin(sin(sub(ARG0, sub(ARG0, sin(sub(0.021601040321409526, sub(sin(sub(ARG0, 0.021601040321409526)), neg(ARG0))))))))), sin(sub(sub(sub(ARG0, 0.021601040321409526), sin(sub(ARG0, sub(ARG0, sin(sin(ARG0)))))), sin(ARG0)))))))))
# -- length=55, height=16
# -- Best Fitness =  0.03101862904895702
#
#
# Currently on run 1 of 30
# -- Best Individual =  mul(sin(mul(sin(sin(sin(sin(sin(sin(sin(sin(sin(mul(sin(sin(sin(sin(ARG0)))), ARG0)))))))))), ARG0)), 0.30161002020986494)
# -- length=21, height=17
# -- Best Fitness =  0.06272246201198345
#
#
# Currently on run 2 of 30
# -- Best Individual =  mul(sin(sin(sin(sin(sin(0.4024286398868344))))), sin(mul(ARG0, sin(sin(sin(sin(sin(sin(sin(sin(sin(sin(sin(add(add(0.840432507715974, sin(ARG0)), cos(ARG0))))))))))))))))
# -- length=28, height=17
# -- Best Fitness =  0.051624639831384427
#
#
# Currently on run 3 of 30
# -- Best Individual =  mul(sin(neg(protectedDiv(sin(sin(add(sin(sin(ARG0)), sin(sin(add(neg(protectedDiv(sin(sin(ARG0)), cos(neg(ARG0)))), sin(sin(sin(ARG0))))))))), cos(neg(neg(ARG0)))))), 0.4011472524095482)
# -- length=30, height=14
# -- Best Fitness =  0.041613920394780776
#
#
# Currently on run 4 of 30
# -- Best Individual =  mul(sin(sin(sin(sin(sin(sin(sin(sin(sin(ARG0))))))))), 0.262503194599222)
# -- length=12, height=10
# -- Best Fitness =  0.08773433431689907
#
#
# Currently on run 5 of 30
# -- Best Individual =  mul(sin(mul(sin(sin(cos(protectedDiv(sin(add(0.5307209764919243, add(sin(add(ARG0, sin(sin(cos(protectedDiv(ARG0, ARG0)))))), ARG0))), mul(sin(mul(ARG0, sin(sin(sin(ARG0))))), add(add(0.5307209764919243, ARG0), 0.18667979341938956)))))), protectedDiv(protectedDiv(ARG0, 0.3201610416217924), protectedDiv(ARG0, 0.22586898941122047)))), sin(cos(protectedDiv(sin(add(add(0.5307209764919243, ARG0), 0.18667979341938956)), mul(sin(sin(cos(protectedDiv(0.3201610416217924, mul(add(sin(mul(ARG0, sin(sin(sin(ARG0))))), ARG0), protectedDiv(protectedDiv(add(add(0.5307209764919243, ARG0), 0.18667979341938956), add(0.5307209764919243, ARG0)), add(add(add(0.5307209764919243, ARG0), protectedDiv(ARG0, ARG0)), ARG0))))))), protectedDiv(protectedDiv(ARG0, 0.3201610416217924), protectedDiv(ARG0, 0.22586898941122047)))))))
# -- length=92, height=16
# -- Best Fitness =  0.043244548031883816
#
#
# Currently on run 6 of 30
# -- Best Individual =  mul(cos(mul(0.19060265945765276, ARG0)), mul(mul(0.9610714877536181, sin(sin(mul(ARG0, sin(sin(sin(0.19060265945765276))))))), sin(mul(ARG0, sin(sin(sin(sin(sin(sin(sin(mul(ARG0, sin(sin(sin(sin(ARG0))))))))))))))))
# -- length=33, height=16
# -- Best Fitness =  0.04277426535821558
#
#
# Currently on run 7 of 30
# -- Best Individual =  mul(0.2022148283346411, sin(add(add(sin(add(ARG0, sin(add(sin(sin(ARG0)), add(sin(add(sin(add(ARG0, ARG0)), sin(ARG0))), sin(ARG0)))))), sin(add(ARG0, sin(sin(add(sin(sin(sin(add(sin(sin(ARG0)), ARG0)))), add(sin(add(ARG0, ARG0)), sin(ARG0)))))))), add(sin(add(ARG0, sin(sin(add(add(sin(add(ARG0, ARG0)), sin(add(sin(sin(sin(ARG0))), sin(ARG0)))), sin(add(sin(sin(ARG0)), add(sin(add(ARG0, ARG0)), sin(ARG0))))))))), sin(sin(add(ARG0, sin(sin(add(sin(ARG0), add(sin(add(ARG0, ARG0)), sin(ARG0))))))))))))
# -- length=93, height=15
# -- Best Fitness =  0.052952101186158194
#
#
# Currently on run 8 of 30
# -- Best Individual =  mul(cos(neg(sub(sub(cos(ARG0), add(ARG0, 0.5340758451451736)), sub(mul(0.46954777248390056, ARG0), sub(0.7013158246876485, ARG0))))), 0.21291463817705747)
# -- length=18, height=6
# -- Best Fitness =  0.07705139663348361
#
#
# Currently on run 9 of 30
# -- Best Individual =  mul(0.4484001109637169, sin(sub(sub(ARG0, sin(mul(mul(sub(sin(ARG0), 0.17527442849360497), cos(0.8599254975042747)), sin(0.8599254975042747)))), sin(ARG0))))
# -- length=19, height=9
# -- Best Fitness =  0.036492735456391194
#
#
# Currently on run 10 of 30
# -- Best Individual =  mul(sin(neg(protectedDiv(sub(protectedDiv(0.9887922785520152, ARG0), mul(0.7827161645787627, ARG0)), cos(cos(sin(neg(sin(neg(protectedDiv(sub(protectedDiv(ARG0, ARG0), mul(0.16740287895963257, ARG0)), cos(cos(0.22935023487054584)))))))))))), 0.22935023487054584)
# -- length=29, height=13
# -- Best Fitness =  0.056688918380460515
#
#
# Currently on run 11 of 30
# -- Best Individual =  mul(sub(0.36477459222122344, mul(cos(add(ARG0, sin(add(ARG0, sub(sub(mul(add(ARG0, sub(mul(sub(mul(0.8006578647894974, 0.22843551233840442), ARG0), 0.22843551233840442), sin(0.29007332118835616))), sin(sin(add(ARG0, sub(sin(sin(ARG0)), ARG0))))), sin(sin(ARG0))), sin(sin(sin(sin(sin(ARG0)))))))))), 0.29007332118835616)), sin(add(ARG0, sub(sub(mul(0.29007332118835616, 0.29007332118835616), sin(sin(add(ARG0, sub(sin(add(ARG0, sub(sin(ARG0), ARG0))), sin(mul(0.29007332118835616, 0.29007332118835616))))))), sin(sin(ARG0))))))
# -- length=71, height=16
# -- Best Fitness =  0.012457241237525148
#
#
# Currently on run 12 of 30
# -- Best Individual =  mul(0.1633823016728284, sin(sin(sin(ARG0))))
# -- length=6, height=4
# -- Best Fitness =  0.08908510112388658
#
#
# Currently on run 13 of 30
# -- Best Individual =  mul(0.09520824613705214, 0.14053901149240655)
# -- length=3, height=1
# -- Best Fitness =  0.10126303699388935
#
#
# Currently on run 14 of 30
# -- Best Individual =  mul(sin(mul(ARG0, sin(sin(sin(sin(sin(sin(mul(neg(cos(ARG0)), sin(ARG0)))))))))), 0.2718686558642873)
# -- length=17, height=12
# -- Best Fitness =  0.048683189327697676
#
#
# Currently on run 15 of 30
# -- Best Individual =  mul(sin(sin(ARG0)), 0.14801700884397195)
# -- length=5, height=3
# -- Best Fitness =  0.08946014799697281
#
#
# Currently on run 16 of 30
# -- Best Individual =  protectedDiv(sin(sin(sin(sin(sin(ARG0))))), protectedDiv(cos(cos(protectedDiv(cos(cos(protectedDiv(sin(protectedDiv(cos(cos(protectedDiv(cos(cos(protectedDiv(sin(ARG0), 0.21276164303836687))), 0.21276164303836687))), 0.21276164303836687)), 0.21276164303836687))), 0.21276164303836687))), 0.21276164303836687))
# -- length=30, height=17
# -- Best Fitness =  0.0828870542309159
#
#
# Currently on run 17 of 30
# -- Best Individual =  mul(mul(add(mul(sin(mul(sin(sin(sin(sin(sin(ARG0))))), ARG0)), sin(mul(sin(sin(sin(sin(sin(sin(mul(sin(sin(sin(sin(ARG0)))), ARG0))))))), ARG0))), cos(sin(sin(sin(sin(mul(sin(sin(ARG0)), sin(protectedDiv(neg(mul(mul(0.42448961205154756, sin(sin(sin(ARG0)))), protectedDiv(add(0.16115099015193046, 0.994498605441202), sub(0.994498605441202, ARG0)))), neg(neg(add(mul(ARG0, 0.13381857538742614), cos(0.2338321199953668))))))))))))), 0.2212036265296482), sin(mul(sin(sin(sin(sin(sin(sin(sin(mul(sin(sin(sin(sin(ARG0)))), ARG0)))))))), ARG0)))
# -- length=81, height=17
# -- Best Fitness =  0.0383984589184509
#
#
# Currently on run 18 of 30
# -- Best Individual =  protectedDiv(sin(sin(sin(sin(add(0.4457019339898548, sub(neg(0.7477095428253266), add(ARG0, ARG0))))))), protectedDiv(0.4457019339898548, 0.09225616044688245))
# -- length=16, height=8
# -- Best Fitness =  0.06600234166141913
#
#
# Currently on run 19 of 30
# -- Best Individual =  mul(sin(sin(sin(sin(0.4173679914721652)))), sin(neg(add(neg(add(sin(neg(add(ARG0, ARG0))), ARG0)), ARG0))))
# -- length=18, height=9
# -- Best Fitness =  0.04832098910865096
#
#
# Currently on run 20 of 30
# -- Best Individual =  mul(sin(sin(sin(sin(sin(sin(sin(sin(ARG0)))))))), neg(cos(ARG0)))
# -- length=13, height=9
# -- Best Fitness =  0.05088135207118511
#
#
# Currently on run 21 of 30
# -- Best Individual =  mul(sin(add(add(protectedDiv(sin(sin(sin(sin(sin(sin(sin(ARG0))))))), ARG0), add(protectedDiv(sin(sin(sin(sin(sin(add(add(sin(sin(ARG0)), neg(ARG0)), add(sub(sin(ARG0), 0.00430689595568523), neg(ARG0)))))))), ARG0), neg(ARG0))), add(sub(sin(sin(sin(sin(sin(sin(sin(ARG0))))))), sin(ARG0)), neg(ARG0)))), 0.2508767804289216)
# -- length=53, height=15
# -- Best Fitness =  0.04784634100051585
#
#
# Currently on run 22 of 30
# -- Best Individual =  mul(sub(0.5857406931959346, sin(sin(neg(mul(sin(sin(sin(neg(add(ARG0, ARG0))))), sin(add(ARG0, mul(0.21997697526097948, ARG0)))))))), sin(sin(sin(neg(mul(0.5857406931959346, sin(add(ARG0, ARG0))))))))
# -- length=30, height=11
# -- Best Fitness =  0.025564243519288182
#
#
# Currently on run 23 of 30
# -- Best Individual =  mul(0.19973186827933753, sin(add(sin(add(sin(add(add(sin(sin(sin(add(sin(ARG0), ARG0)))), sin(sin(ARG0))), sin(add(sin(sin(ARG0)), ARG0)))), sin(add(sin(ARG0), sin(add(sin(sin(ARG0)), sin(add(sin(sin(sin(ARG0))), ARG0)))))))), add(sin(add(sin(add(sin(add(sin(ARG0), add(sin(add(ARG0, sin(add(sin(sin(ARG0)), sin(0.06118729433868242))))), sin(add(sin(sin(sin(ARG0))), ARG0))))), add(sin(add(ARG0, sin(0.06118729433868242))), sin(ARG0)))), 0.0260548400517282)), add(sin(add(ARG0, sin(add(add(sin(sin(add(sin(add(sin(ARG0), ARG0)), 0.0260548400517282))), sin(ARG0)), sin(sin(ARG0)))))), sin(add(sin(sin(add(sin(ARG0), add(sin(add(sin(ARG0), ARG0)), sin(add(sin(sin(sin(ARG0))), ARG0)))))), ARG0)))))))
# -- length=119, height=17
# -- Best Fitness =  0.053177869548129406
#
#
# Currently on run 24 of 30
# -- Best Individual =  mul(sin(sub(sub(ARG0, sin(sin(sub(ARG0, sub(sin(sin(ARG0)), sin(sin(sin(ARG0)))))))), sin(sin(sin(sin(sub(sin(sub(ARG0, sub(0.14867122896867413, sin(sin(sin(sub(ARG0, sin(sin(ARG0))))))))), sin(0.08540201711921291)))))))), cos(neg(cos(0.08540201711921291))))
# -- length=41, height=17
# -- Best Fitness =  0.032446622626484956
#
#
# Currently on run 25 of 30
# -- Best Individual =  mul(add(sin(add(sin(ARG0), add(sin(sin(add(sin(ARG0), ARG0))), add(sin(sin(add(sin(add(sin(sin(add(ARG0, sin(ARG0)))), sin(ARG0))), ARG0))), add(add(sin(sin(ARG0)), sin(sin(add(add(0.15969461480572955, ARG0), ARG0)))), sin(add(0.03668304913982956, add(add(sin(sin(add(ARG0, sin(sin(sin(ARG0)))))), sin(sin(sin(mul(sin(sin(ARG0)), ARG0))))), sin(sin(sin(ARG0))))))))))), sin(add(sin(sin(mul(sin(sin(add(sin(sin(sin(sin(ARG0)))), sin(sin(add(add(sin(add(add(0.15969461480572955, ARG0), sin(ARG0))), ARG0), sin(ARG0))))))), ARG0))), sin(ARG0)))), 0.23149739856030793)
# -- length=96, height=17
# -- Best Fitness =  0.02783935471475429
#
#
# Currently on run 26 of 30
# -- Best Individual =  mul(0.6053610512804172, neg(mul(sin(ARG0), cos(ARG0))))
# -- length=8, height=4
# -- Best Fitness =  0.04831475247129512
#
#
# Currently on run 27 of 30
# -- Best Individual =  protectedDiv(sin(sin(sin(ARG0))), add(sin(add(sin(sin(sin(add(mul(cos(sin(add(0.8788426255453692, ARG0))), 0.8788426255453692), ARG0)))), sin(add(0.8788426255453692, add(mul(cos(sin(add(0.8788426255453692, ARG0))), cos(sin(add(0.8788426255453692, ARG0)))), ARG0))))), add(add(sin(sin(add(sin(sin(sin(sin(sin(add(0.8788426255453692, add(cos(sin(ARG0)), ARG0))))))), sin(add(0.8788426255453692, add(mul(cos(sin(ARG0)), 0.8788426255453692), ARG0)))))), add(sin(sin(cos(ARG0))), sin(ARG0))), ARG0)))
# -- length=71, height=16
# -- Best Fitness =  0.024639824103506514
#
#
# Currently on run 28 of 30
# -- Best Individual =  mul(sin(protectedDiv(protectedDiv(sin(sin(0.5501373666191974)), sub(sub(0.701915855999703, ARG0), sin(sin(sin(protectedDiv(sin(sin(0.5501373666191974)), sub(sub(protectedDiv(0.18973460609157378, 0.21968078622431453), ARG0), sin(0.5501373666191974)))))))), mul(cos(protectedDiv(0.18973460609157378, 0.21968078622431453)), mul(cos(protectedDiv(sin(sin(sin(0.21968078622431453))), sin(sin(protectedDiv(sin(0.5501373666191974), sub(sub(0.701915855999703, ARG0), sin(sin(sin(protectedDiv(sin(sin(0.5501373666191974)), sub(sub(0.701915855999703, ARG0), 0.701915855999703))))))))))), sin(neg(ARG0)))))), 0.39718240050325204)
# -- length=63, height=17
# -- Best Fitness =  0.051850967802674584
#
#
# Currently on run 29 of 30
# -- Best Individual =  mul(sub(sub(0.32956623195741097, sin(sin(cos(ARG0)))), sin(sin(sin(protectedDiv(sin(protectedDiv(sub(neg(0.32956623195741097), ARG0), 0.32956623195741097)), ARG0))))), sin(sin(sin(sin(sin(sin(sin(sin(sin(sin(sin(sin(sin(ARG0))))))))))))))
# -- length=34, height=14
# -- Best Fitness =  0.03417836735052821

# %% [markdown]
# Create our graphs using the averages across all the runs. Notice how we use standard deviation to show how much variation there is in the runs.
#
# Notice that if there's a big discrepancy between best and average the graphs can look like there's virtually no variation in the best score. If this happens, the first thing to do is verify if that is actually happening; you can do that by commenting out this line:
#
# **plt.errorbar(x, avgArray.mean(0), yerr=stdArray.mean(0),label="Average",color="Red")**

# %%
minBest = min(bestIndividualsForNRuns, key = lambda val: val[1])
print(f'Best individual from all runs: {minBest}')

plt.plot(dataNumpy[:,0], dataNumpy[:,1])
# for bestInd in bestIndividualsForNRuns:
#     plt.plot(dataNumpy[:,0], bestInd[0])
plt.plot(dataNumpy[:,0], minBest[0])
plt.title("Predicted vs Targeted functions")
plt.legend(['targeted', 'predicted'], loc = 'upper right')
plt.show()
# Out:
# Best individual from all runs: ([0.005096932980793865, -0.009414904054373426, -0.02204926809668506, -0.031938608749495154, -0.039677197339087276, -0.0468791432133487, -0.055329494907200884, -0.06620868748812953, -0.07948515550780212, -0.09345747548024248, -0.10454072069159413, -0.10750233862744325, -0.09631677586782014, -0.06559182008944549, -0.012210954985739791, 0.06338260538097998, 0.15679608325410285, 0.2604067039730817, 0.3649520275980937, 0.4613986077822275, 0.5424214877271486, 0.6030597977314681, 0.6405258336024171, 0.6535237704368135, 0.641592874602435, 0.6048561970295541, 0.5442102833988959, 0.46165710545301525, 0.3604083130429483, 0.24464006224895746, 0.11909393933285937, -0.011204811027522485, -0.14103387666902387, -0.2650093140418977, -0.37775383582238176, -0.474241361379526, -0.550199892542796, -0.6024205137940016, -0.6289154406966332, -0.6289770556877494, -0.6032179088223386, -0.553619197010901, -0.483540696671377, -0.3976041149987711, -0.30138014188563267, -0.20087899680871027, -0.10192836527969015, -0.009575433044677542, 0.07235548098273999, 0.14147266438355993, 0.19678670412605148, 0.2384839126133104, 0.2675657551317631, 0.28540767816187007, 0.2932698542574292, 0.2917802433384049, 0.280443354468414, 0.2573813327344158, 0.21990234305601844, 0.16705201182834917, 0.10481659257882683, 0.049649843880480875, 0.01804707354695272, 0.0030737787376972493, -0.02367823702076238, -0.07436559232766674, -0.1318248676088026, -0.1744459525867763, -0.19345144734534198, -0.1910650520867558, -0.17395160009491129, -0.1489578765607832, -0.12126032651602243, -0.09396620416653938, -0.0684300285769389, -0.04478402261532987, -0.022417934128922967, -0.0003192469007924475, 0.02272376341165467, 0.04800716843115658, 0.07679866955396127, 0.11011663433338627, 0.14831802267718178, 0.19053270863752944, 0.23417826861288615, 0.27494291959690076, 0.3075577534390171, 0.327308067241678, 0.331681461883057, 0.3210559355482524, 0.29710493832352747, 0.2582133691792807, 0.19469589768025758, 0.09452329592926982, -0.033094611868693904, -0.14937661604385485, -0.2258410272991, -0.2710521119573099, -0.30592313124238535, -0.33975440695448483], 0.012457241237525148)

# %%
# Genetic Programming is done (all runs) - plot statistics:
x = numpy.arange(0, MAX_GENERATIONS+1)
avgArray = numpy.array(avgListFitness)
stdArray = numpy.array(stdListFitness)
minArray = numpy.array(minListFitness)
maxArray = numpy.array(maxListFitness)
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Best and Average Fitness for Symbolic Regression')
#plt.errorbar(x, avgArray.mean(0), yerr=stdArray.mean(0),label="Average",color="Red")
plt.errorbar(x, minArray.mean(0), yerr=minArray.std(0),label="Best", color="Green")
plt.show()

# %% [markdown]
# Show the graph for size.

# %%
# Genetic Programming is done (all runs) - plot statistics:
x = numpy.arange(0, MAX_GENERATIONS+1)
avgArray = numpy.array(avgListSize)
stdArray = numpy.array(stdListSize)
minArray = numpy.array(minListSize)
maxArray = numpy.array(maxListSize)
plt.xlabel('Generation')
plt.ylabel('Size')
plt.title('Best and Average Size for Symbolic Regression')
plt.errorbar(x, avgArray.mean(0), yerr=stdArray.mean(0),label="Average",color="Red")
plt.errorbar(x, minArray.mean(0), yerr=minArray.std(0),label="Best", color="Blue")
plt.show()
